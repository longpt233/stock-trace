# %%
pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-1.8.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 5.3 MB/s
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.1.5)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.0.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (0.29.24)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (57.4.0)
# Collecting statsmodels!=0.12.0,>=0.11
#   Downloading statsmodels-0.13.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 15.6 MB/s
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->pmdarima) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.19->pmdarima) (1.15.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Installing collected packages: statsmodels, pmdarima
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed pmdarima-1.8.3 statsmodels-0.13.0

# %% [markdown]
# # **Load data**

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/longpt233/stock-trace/main/data/vndirect/all/ACB.csv?token=ANSU5LSS67NJAIFAOWWINLTBNDYEI'
#stock_data = pd.read_csv(url, index_col=0, parse_dates=[0])
stock_data = pd.read_csv(url)
stock_data.head(10)
# Out:
#    2013-01-02  5.168  17.3   6.135  ...  16.3  17.4  16.3.1  2678800.0
# 0  2013-01-03  5.078  17.0 -1.7341  ...  17.5  17.8    16.7  1967363.0
# 1  2013-01-04  5.138  17.2  1.1765  ...  16.9  17.2    16.7  1170195.0
# 2  2013-01-07  5.138  17.2  0.5848  ...  17.0  17.5    17.0  1356102.0
# 3  2013-01-08  5.168  17.3  1.1696  ...  17.1  17.5    16.9  2180418.0
# 4  2013-01-09  5.409  18.1  5.8480  ...  17.1  18.2    17.1  3961702.0
# 5  2013-01-10  5.468  18.3  1.1050  ...  18.1  18.3    17.7   880926.0
# 6  2013-01-11  5.437  18.2  0.0000  ...  19.0  19.0    18.2   806261.0
# 7  2013-01-14  5.377  18.0 -1.0989  ...  18.4  18.4    17.7   614513.0
# 8  2013-01-15  5.437  18.2  1.1111  ...  18.2  18.3    17.6  1330521.0
# 9  2013-01-16  5.437  18.2  0.0000  ...  18.2  18.8    18.1  1397024.0
#
# [10 rows x 13 columns]

# %%
stock_data.columns= ['date', 'adjust', 'close', 'change_perc', 'avg', 'volume_match', 'value_match', 'volume_reconcile', 'value_reconcile', 'open', 'high', 'low', 'volume']

stock_data.head(5)
# Out:
#          date  adjust  close  change_perc  ...  open  high   low     volume
# 0  2013-01-03   5.078   17.0      -1.7341  ...  17.5  17.8  16.7  1967363.0
# 1  2013-01-04   5.138   17.2       1.1765  ...  16.9  17.2  16.7  1170195.0
# 2  2013-01-07   5.138   17.2       0.5848  ...  17.0  17.5  17.0  1356102.0
# 3  2013-01-08   5.168   17.3       1.1696  ...  17.1  17.5  16.9  2180418.0
# 4  2013-01-09   5.409   18.1       5.8480  ...  17.1  18.2  17.1  3961702.0
#
# [5 rows x 13 columns]

# %%
#Lấy giá đóng cửa để dự đoán
close_data = stock_data[['date','close']]

close_data.head(5)
# Out:
#          date  close
# 0  2013-01-03   17.0
# 1  2013-01-04   17.2
# 2  2013-01-07   17.2
# 3  2013-01-08   17.3
# 4  2013-01-09   18.1

# %%
#Kiểm tra giá trị Nan có tồn tại không
close_data.isna().sum()
# Out:
# date     0
# close    0
# dtype: int64

# %%
from datetime import datetime as dt

#Chuyển time về dạng chuẩn python
close_data['date'] = pd.to_datetime(close_data['date']).dt.date

close_data.head(5)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#          date  close
# 0  2013-01-03   17.0
# 1  2013-01-04   17.2
# 2  2013-01-07   17.2
# 3  2013-01-08   17.3
# 4  2013-01-09   18.1

# %%
#Đặt date làm index cho chuỗi thời gian
close_data = close_data.set_index('date', drop=True)

close_data
# Out:
#             close
# date
# 2013-01-03  17.00
# 2013-01-04  17.20
# 2013-01-07  17.20
# 2013-01-08  17.30
# 2013-01-09  18.10
# ...           ...
# 2021-09-27  31.50
# 2021-09-28  31.60
# 2021-09-29  31.35
# 2021-09-30  31.55
# 2021-10-01  31.50
#
# [2177 rows x 1 columns]

# %% [markdown]
# **Create train_set, test_set**
#
# *   Chỉ lấy dữ liệu bắt đầu từ năm 2019 -> 2021
# *   Tách 1 tháng cuối (1/9/2021->1/10/2021) làm tập test, còn lại cho train

# %%
type(close_data.index.values)
# Out:
# numpy.ndarray

# %%
train_set = close_data[(close_data.index.values < dt.strptime('2021-09-01', '%Y-%m-%d').date()) & (close_data.index.values >= dt.strptime('2019-01-01', '%Y-%m-%d').date())]

train_set
# Out:
#             close
# date
# 2019-01-02  29.20
# 2019-01-03  28.10
# 2019-01-04  28.30
# 2019-01-07  28.70
# 2019-01-08  28.50
# ...           ...
# 2021-08-25  32.45
# 2021-08-26  31.95
# 2021-08-27  31.75
# 2021-08-30  32.15
# 2021-08-31  32.00
#
# [661 rows x 1 columns]

# %%
test_set = close_data[(close_data.index.values >= dt.strptime('2021-09-01', '%Y-%m-%d').date())]

test_set
# Out:
#             close
# date
# 2021-09-01  32.00
# 2021-09-06  32.05
# 2021-09-07  32.50
# 2021-09-08  32.15
# 2021-09-09  32.45
# 2021-09-10  32.30
# 2021-09-13  31.90
# 2021-09-14  31.50
# 2021-09-15  31.20
# 2021-09-16  31.30
# 2021-09-17  31.60
# 2021-09-20  32.10
# 2021-09-21  31.80
# 2021-09-22  31.60
# 2021-09-23  31.60
# 2021-09-24  32.00
# 2021-09-27  31.50
# 2021-09-28  31.60
# 2021-09-29  31.35
# 2021-09-30  31.55
# 2021-10-01  31.50

# %% [markdown]
# Nhận thấy dữ liệu còn thiếu nhiều ngày không có giá trị, mặc định thêm với giá trị 0

# %%
#Thêm cả những ngày không có giá đóng cửa nào vào DF
srt_date = dt.strptime('2019-01-01', '%Y-%m-%d').date()
end_date = train_set.index.max()
idx = pd.date_range(srt_date, end_date)

train_set.index = pd.DatetimeIndex(train_set.index)
train_set = train_set.reindex(idx, fill_value=0)

train_set.head(5)
# Out:
#             close
# 2019-01-01    0.0
# 2019-01-02   29.2
# 2019-01-03   28.1
# 2019-01-04   28.3
# 2019-01-05    0.0

# %%
srt_date = test_set.index.min()
end_date = test_set.index.max()
idx = pd.date_range(srt_date, end_date)

test_set.index = pd.DatetimeIndex(test_set.index)
test_set = test_set.reindex(idx, fill_value=0)

test_set.head(5)
# Out:
#             close
# 2021-09-01   32.0
# 2021-09-02    0.0
# 2021-09-03    0.0
# 2021-09-04    0.0
# 2021-09-05    0.0

# %% [markdown]
# # **Check for Stationary**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#Visualize data
plt.figure(figsize=(21, 7))
plt.plot(train_set['close'])

# %% [markdown]
# Có thể thấy chuỗi tăng giảm không ổn định cho lắm. Tuy nhiên cần kiểm chứng chắc chắn hơn :
#
# *   Phân tách chuỗi thành các thành phần
# *   Thực hiện kiểm tra ADF

# %% [markdown]
# Phân tích chuỗi thành **3 thành phần** : xu hướng (**trend**), thời vụ (**seasonality**) và còn lại (**residual**)

# %%
import seaborn as sns
import statsmodels.api as sm
import warnings
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
decomp = seasonal_decompose(train_set['close'])
fig = decomp.plot()
fig.set_size_inches(14, 7)

# %%
#Vẽ 3 tháng đầu
decomp = seasonal_decompose(train_set['close'][:90])
fig = decomp.plot()
fig.set_size_inches(14, 7)

# %% [markdown]
# Có thể thấy từ 2 biểu đồ trên, chuỗi có vẻ có xu hướng tăng và có tính thời vụ theo tuần. Tuy nhiên cần kiểm chứng cụ thể hơn và bỏ tính thời vụ của chuỗi

# %% [markdown]
# Kiểm tra tính ổn định bằng giả thuyết **Augmented Dickey-Fuller Test**

# %%
from statsmodels.tsa.stattools import adfuller

fuller_test = adfuller(train_set['close'])

print('ADF Statistic: %f' % fuller_test[0])
print('p-value: %f' % fuller_test[1])
# Out:
# ADF Statistic: -3.340369
# p-value: 0.013168

# %% [markdown]
# Do giá trị p-value < 0.05 nên chuỗi ổn định

# %%
#Định nghĩa 1 hàm kiểm tra tính ổn định của chuỗi
def test_p_value(data):
  fuller_test = adfuller(data)
  print('p-value : %.5f' % fuller_test[1])
  if(fuller_test[1] <= 0.05):
    print('Chuỗi ổn định')
  else:
    print('Chuỗi KHÔNG ổn định')

# %%
#test
test_p_value(train_set['close'])
# Out:
# p-value : 0.01317
# Chuỗi ổn định

# %% [markdown]
# Để bỏ tính thời vụ của chuỗi cũng như để chuỗi ổn định, ta áp dụng Difference. Ở đây, áp dụng **Seasonal Differencing**

# %%
train_set['Seasonal_diff'] = train_set['close'] - train_set['close'].shift(7)

train_set.head(10)
# Out:
#             close  Seasonal_diff
# 2019-01-01    0.0            NaN
# 2019-01-02   29.2            NaN
# 2019-01-03   28.1            NaN
# 2019-01-04   28.3            NaN
# 2019-01-05    0.0            NaN
# 2019-01-06    0.0            NaN
# 2019-01-07   28.7            NaN
# 2019-01-08   28.5           28.5
# 2019-01-09   29.0           -0.2
# 2019-01-10   28.9            0.8

# %%
#Seasonal Difference
plt.figure(figsize=[21,7])
train_set['Seasonal_diff'].plot()
#train_set['Seasonal_diff'][91:121].plot()

#Xác định tính ổn định của chuỗi
test_p_value(train_set['Seasonal_diff'].dropna())
# Out:
# p-value : 0.00000
# Chuỗi ổn định

# %% [markdown]
# Có thể thấy chuỗi đã không còn tính thời vụ theo tuần

# %% [markdown]
# # **Xây dựng model SARIMA**

# %% [markdown]
# **Chọn bộ tham số SARIMA(p,d,q)x(P,D,Q,s)**
#
# Ta thực hiện theo 2 bước :
#
# 1.   Chọn bộ số khởi tạo ban đầu
# 2.   Tìm kiếm lưới để tìm bộ số tối ưu cho model
#
# Vì chuỗi ổn định nên không cần áp dụng Difference => d = 0
# Do đã áp dụng Seasonal Differencing 1 lần nên D = 1
# Chọn p,q khởi tạo bằng cách áp dụng biểu đồ ACF (chọn q, Q) và PACF (chọn p, P)

# %%
#Vẽ ACF và PACF
q_para = plot_acf(train_set['Seasonal_diff'].dropna())

p_para = plot_pacf(train_set['Seasonal_diff'].dropna())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# Qua 2 biểu đồ trên, nhận thấy :
#
# *   **PACF** có mức tăng đột biến âm đáng kể tại các vị trí **lag(độ trễ) 7, 14, 21**,... (đây là suy giảm cấp mũ _ *expotential decay*) ; và bên cạnh đó ở biểu đồ **ACF** có mức tăng đột biến âm đáng kể tại **lag 7**, qua đó cho thấy giá trị **Q = 1** (thể hiện tính thời vụ theo tuần) và giá trị **P = 0**
# *   **PACF** và **ACF** đều có mức tăng đột biến dương đáng kể tại **lag 1** nên **p = q = 1**
# *   Vì có vị trí lag tương ứng là 7,14,21,... nên **s = 7** (tính thời vụ theo tuần)
#
# ==> Ta có bộ tham số khởi tạo ban đầu : **SARIMA(1,0,1)x(0,1,1,7)**

# %% [markdown]
# **Mô hình SARIMA sơ bộ**
#
# *   Triển khai mô hình SARIMA sơ bộ sử dụng các thông số xác định từ các ô ACF và PACF.
# *   Kiểm tra chất lượng của mô hình bằng các đồ thị ACF và PACF mới về phần còn lại của mô hình (*model's residuals*).

# %%
# fit SARIMA dựa trên tham số khởi tạo
sar = sm.tsa.statespace.SARIMAX(train_set['close'], 
                                order=(1,0,1), 
                                seasonal_order=(0,1,1,7)).fit(max_iter = 50, method = 'powell')
sar.summary()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/optimizer.py:23: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method powell is: xtol, ftol, maxfun, start_direc. The list of unsupported keyword arguments passed include: max_iter. After release 0.14, this will raise.
#   FutureWarning
# Optimization terminated successfully.
#          Current function value: 3.008239
#          Iterations: 4
#          Function evaluations: 188
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             close   No. Observations:                  974
# Model:             SARIMAX(1, 0, 1)x(0, 1, 1, 7)   Log Likelihood               -2930.025
# Date:                           Fri, 15 Oct 2021   AIC                           5868.050
# Time:                                   04:19:30   BIC                           5887.547
# Sample:                               01-01-2019   HQIC                          5875.472
#                                     - 08-31-2021
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4584      0.035     13.004      0.000       0.389       0.527
# ma.L1          0.0734      0.043      1.690      0.091      -0.012       0.159
# ma.S.L7       -0.8948      0.014    -66.001      0.000      -0.921      -0.868
# sigma2        24.7227      0.469     52.738      0.000      23.804      25.641
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.44   Jarque-Bera (JB):              9575.08
# Prob(Q):                              0.50   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.87   Skew:                            -2.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#Kiểm tra chất lượng qua residual
res = sar.resid

f1 = plot_acf(res.dropna())

f2 = plot_pacf(res.dropna())
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/graphics/tsaplots.py:353: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   FutureWarning,

# %% [markdown]
# Có thể thấy đã hầu như không còn các đột biến đáng kể tại ở cả 2 biểu đồ ACF và PACF nên bộ tham số **(1,0,1)x(0,1,1,7)** có thể chấp nhận làm bộ tham số khởi tạo để tìm kiếm lưới

# %% [markdown]
# **Grid Search**

# %%
#Grid search bằng thư viện có sẵn 
from pmdarima import auto_arima
  
#Ignore harmless warnings
warnings.filterwarnings("ignore")
  
#Fit auto_arima function to AirPassengers dataset
stepwise_fit = auto_arima(train_set['close'], start_p = 1, start_q = 1,
                          max_p = 3, max_q = 3, m = 7,
                          start_P = 0, start_Q = 1,
                          max_P = 3, max_Q = 3, seasonal = True,
                          d = 0, D = 1, trace = True,
                          error_action ='ignore')           # set to stepwise
  
# To print the summary
stepwise_fit.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[7] intercept   : AIC=5868.164, Time=1.74 sec
#  ARIMA(0,0,0)(0,1,0)[7] intercept   : AIC=6648.859, Time=0.07 sec
#  ARIMA(1,0,0)(1,1,0)[7] intercept   : AIC=6145.143, Time=1.10 sec
#  ARIMA(0,0,1)(0,1,1)[7] intercept   : AIC=5903.534, Time=0.90 sec
#  ARIMA(0,0,0)(0,1,0)[7]             : AIC=6646.898, Time=0.07 sec
#  ARIMA(1,0,1)(0,1,0)[7] intercept   : AIC=6438.476, Time=0.47 sec
#  ARIMA(1,0,1)(1,1,1)[7] intercept   : AIC=5868.451, Time=1.78 sec
#  ARIMA(1,0,1)(0,1,2)[7] intercept   : AIC=5868.509, Time=3.15 sec
#  ARIMA(1,0,1)(1,1,0)[7] intercept   : AIC=6142.268, Time=1.32 sec
#  ARIMA(1,0,1)(1,1,2)[7] intercept   : AIC=5865.237, Time=5.48 sec
#  ARIMA(1,0,1)(2,1,2)[7] intercept   : AIC=5867.237, Time=7.73 sec
#  ARIMA(1,0,1)(1,1,3)[7] intercept   : AIC=5867.237, Time=10.10 sec
#  ARIMA(1,0,1)(0,1,3)[7] intercept   : AIC=5870.313, Time=5.36 sec
#  ARIMA(1,0,1)(2,1,1)[7] intercept   : AIC=5870.208, Time=3.90 sec
#  ARIMA(1,0,1)(2,1,3)[7] intercept   : AIC=inf, Time=19.25 sec
#  ARIMA(0,0,1)(1,1,2)[7] intercept   : AIC=5901.001, Time=4.44 sec
#  ARIMA(1,0,0)(1,1,2)[7] intercept   : AIC=5863.446, Time=4.01 sec
#  ARIMA(1,0,0)(0,1,2)[7] intercept   : AIC=5866.587, Time=1.93 sec
#  ARIMA(1,0,0)(1,1,1)[7] intercept   : AIC=5866.528, Time=1.41 sec
#  ARIMA(1,0,0)(2,1,2)[7] intercept   : AIC=5865.438, Time=4.85 sec
#  ARIMA(1,0,0)(1,1,3)[7] intercept   : AIC=5865.438, Time=8.90 sec
#  ARIMA(1,0,0)(0,1,1)[7] intercept   : AIC=5866.455, Time=1.22 sec
#  ARIMA(1,0,0)(0,1,3)[7] intercept   : AIC=5868.418, Time=4.20 sec
#  ARIMA(1,0,0)(2,1,1)[7] intercept   : AIC=5868.317, Time=2.80 sec
#  ARIMA(1,0,0)(2,1,3)[7] intercept   : AIC=5866.484, Time=18.17 sec
#  ARIMA(0,0,0)(1,1,2)[7] intercept   : AIC=6143.271, Time=3.50 sec
#  ARIMA(2,0,0)(1,1,2)[7] intercept   : AIC=5865.355, Time=4.58 sec
#  ARIMA(2,0,1)(1,1,2)[7] intercept   : AIC=5863.657, Time=8.94 sec
#  ARIMA(1,0,0)(1,1,2)[7]             : AIC=5863.103, Time=2.42 sec
#  ARIMA(1,0,0)(0,1,2)[7]             : AIC=5866.210, Time=1.06 sec
#  ARIMA(1,0,0)(1,1,1)[7]             : AIC=5866.150, Time=0.82 sec
#  ARIMA(1,0,0)(2,1,2)[7]             : AIC=5865.091, Time=3.48 sec
#  ARIMA(1,0,0)(1,1,3)[7]             : AIC=5865.090, Time=6.79 sec
#  ARIMA(1,0,0)(0,1,1)[7]             : AIC=5866.141, Time=0.52 sec
#  ARIMA(1,0,0)(0,1,3)[7]             : AIC=5868.051, Time=2.71 sec
#  ARIMA(1,0,0)(2,1,1)[7]             : AIC=5867.951, Time=1.74 sec
#  ARIMA(1,0,0)(2,1,3)[7]             : AIC=5867.103, Time=7.24 sec
#  ARIMA(0,0,0)(1,1,2)[7]             : AIC=6144.090, Time=2.44 sec
#  ARIMA(2,0,0)(1,1,2)[7]             : AIC=5865.036, Time=3.25 sec
#  ARIMA(1,0,1)(1,1,2)[7]             : AIC=5864.948, Time=3.93 sec
#  ARIMA(0,0,1)(1,1,2)[7]             : AIC=5901.423, Time=2.89 sec
#  ARIMA(2,0,1)(1,1,2)[7]             : AIC=5863.404, Time=6.71 sec
#
# Best model:  ARIMA(1,0,0)(1,1,2)[7]
# Total fit time: 177.410 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                                      y   No. Observations:                  974
# Model:             SARIMAX(1, 0, 0)x(1, 1, [1, 2], 7)   Log Likelihood               -2926.552
# Date:                                Fri, 15 Oct 2021   AIC                           5863.103
# Time:                                        04:27:06   BIC                           5887.474
# Sample:                                             0   HQIC                          5872.381
#                                                 - 974
# Covariance Type:                                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5155      0.012     42.453      0.000       0.492       0.539
# ar.S.L7       -0.9076      0.060    -15.152      0.000      -1.025      -0.790
# ma.S.L7       -0.0181      0.067     -0.271      0.786      -0.149       0.113
# ma.S.L14      -0.7753      0.066    -11.689      0.000      -0.905      -0.645
# sigma2        24.6023      0.489     50.282      0.000      23.643      25.561
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):              9485.03
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.87   Skew:                            -2.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                        17.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#Grid search tay
# SETUP (using itertools to gridsearch solutions)
import itertools

# set parameter range
p = range(1,3)
q = range(0,3)
d = range(0,2)
s = range(7,8)

# list of all parameter combos
pdq = list(itertools.product(p, d, q))
# same for seasonal variant
seasonal_pdq = list(itertools.product(p, d, q, s))

# %%
seasonal_pdq
# Out:
# [(1, 0, 0, 7),
#  (1, 0, 1, 7),
#  (1, 0, 2, 7),
#  (1, 1, 0, 7),
#  (1, 1, 1, 7),
#  (1, 1, 2, 7),
#  (2, 0, 0, 7),
#  (2, 0, 1, 7),
#  (2, 0, 2, 7),
#  (2, 1, 0, 7),
#  (2, 1, 1, 7),
#  (2, 1, 2, 7)]

# %%
warnings.filterwarnings("ignore") # specify to ignore warning messages

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(train_set['close'],
                                            order=param,
                                            seasonal_order=param_seasonal)
            results = mod.fit(max_iter = 50, method = 'powell')

            print('SARIMA{},{}7 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# Optimization terminated successfully.
#          Current function value: 3.314545
#          Iterations: 3
#          Function evaluations: 110
# SARIMA(1, 0, 0),(1, 0, 0, 7)7 - AIC:6462.734093788955
# Optimization terminated successfully.
#          Current function value: 3.038794
#          Iterations: 6
#          Function evaluations: 297
# SARIMA(1, 0, 0),(1, 0, 1, 7)7 - AIC:5927.571084837
# Optimization terminated successfully.
#          Current function value: 3.037753
#          Iterations: 5
#          Function evaluations: 303
# SARIMA(1, 0, 0),(1, 0, 2, 7)7 - AIC:5927.5434762892855
# Optimization terminated successfully.
#          Current function value: 3.150514
#          Iterations: 2
#          Function evaluations: 72
# SARIMA(1, 0, 0),(1, 1, 0, 7)7 - AIC:6143.202230883742
# Optimization terminated successfully.
#          Current function value: 3.007264
#          Iterations: 4
#          Function evaluations: 194
# SARIMA(1, 0, 0),(1, 1, 1, 7)7 - AIC:5866.150152598331
# Optimization terminated successfully.
#          Current function value: 3.006592
#          Iterations: 3
#          Function evaluations: 187
# SARIMA(1, 0, 0),(1, 1, 2, 7)7 - AIC:5866.841748004754
# Optimization terminated successfully.
#          Current function value: 3.173639
#          Iterations: 3
#          Function evaluations: 152
# SARIMA(1, 0, 0),(2, 0, 0, 7)7 - AIC:6190.248550965059
# Optimization terminated successfully.
#          Current function value: 3.037845
#          Iterations: 8
#          Function evaluations: 478
# SARIMA(1, 0, 0),(2, 0, 1, 7)7 - AIC:5927.722503737245
# Optimization terminated successfully.
#          Current function value: 3.035434
#          Iterations: 7
#          Function evaluations: 510
# SARIMA(1, 0, 0),(2, 0, 2, 7)7 - AIC:5925.025758264138
# Optimization terminated successfully.
#          Current function value: 3.103450
#          Iterations: 2
#          Function evaluations: 96
# SARIMA(1, 0, 0),(2, 1, 0, 7)7 - AIC:6053.520524101326
# Optimization terminated successfully.
#          Current function value: 3.007175
#          Iterations: 4
#          Function evaluations: 245
# SARIMA(1, 0, 0),(2, 1, 1, 7)7 - AIC:5867.976222085513
# Optimization terminated successfully.
#          Current function value: 3.006512
#          Iterations: 4
#          Function evaluations: 288
# SARIMA(1, 0, 0),(2, 1, 2, 7)7 - AIC:5868.685990935815
# Optimization terminated successfully.
#          Current function value: 3.310295
#          Iterations: 3
#          Function evaluations: 136
# SARIMA(1, 0, 1),(1, 0, 0, 7)7 - AIC:6456.454921343957
# Optimization terminated successfully.
#          Current function value: 3.038788
#          Iterations: 5
#          Function evaluations: 305
# SARIMA(1, 0, 1),(1, 0, 1, 7)7 - AIC:5929.558708185465
# Optimization terminated successfully.
#          Current function value: 3.037736
#          Iterations: 5
#          Function evaluations: 358
# SARIMA(1, 0, 1),(1, 0, 2, 7)7 - AIC:5929.509628040258
# Optimization terminated successfully.
#          Current function value: 3.148038
#          Iterations: 2
#          Function evaluations: 93
# SARIMA(1, 0, 1),(1, 1, 0, 7)7 - AIC:6140.378427536193
# Optimization terminated successfully.
#          Current function value: 3.008030
#          Iterations: 4
#          Function evaluations: 239
# SARIMA(1, 0, 1),(1, 1, 1, 7)7 - AIC:5869.642818974441
# Optimization terminated successfully.
#          Current function value: 3.006578
#          Iterations: 4
#          Function evaluations: 285
# SARIMA(1, 0, 1),(1, 1, 2, 7)7 - AIC:5868.814617886611
# Optimization terminated successfully.
#          Current function value: 3.171342
#          Iterations: 3
#          Function evaluations: 182
# SARIMA(1, 0, 1),(2, 0, 0, 7)7 - AIC:6187.773864427615
# Optimization terminated successfully.
#          Current function value: 3.038886
#          Iterations: 7
#          Function evaluations: 502
# SARIMA(1, 0, 1),(2, 0, 1, 7)7 - AIC:5931.7491934236805
# Optimization terminated successfully.
#          Current function value: 3.036804
#          Iterations: 7
#          Function evaluations: 584
# SARIMA(1, 0, 1),(2, 0, 2, 7)7 - AIC:5929.694848441728
# Optimization terminated successfully.
#          Current function value: 3.102993
#          Iterations: 3
#          Function evaluations: 185
# SARIMA(1, 0, 1),(2, 1, 0, 7)7 - AIC:6054.630625886345
# Optimization terminated successfully.
#          Current function value: 3.007282
#          Iterations: 4
#          Function evaluations: 293
# SARIMA(1, 0, 1),(2, 1, 1, 7)7 - AIC:5870.186258997382
# Optimization terminated successfully.
#          Current function value: 3.007007
#          Iterations: 4
#          Function evaluations: 328
# SARIMA(1, 0, 1),(2, 1, 2, 7)7 - AIC:5871.649996208813
# Optimization terminated successfully.
#          Current function value: 3.309356
#          Iterations: 3
#          Function evaluations: 191
# SARIMA(1, 0, 2),(1, 0, 0, 7)7 - AIC:6456.6248580599795
# Optimization terminated successfully.
#          Current function value: 3.026240
#          Iterations: 5
#          Function evaluations: 361
# SARIMA(1, 0, 2),(1, 0, 1, 7)7 - AIC:5907.1163625617655
# Optimization terminated successfully.
#          Current function value: 3.023755
#          Iterations: 4
#          Function evaluations: 334
# SARIMA(1, 0, 2),(1, 0, 2, 7)7 - AIC:5904.27538950297
# Optimization terminated successfully.
#          Current function value: 3.141623
#          Iterations: 2
#          Function evaluations: 114
# SARIMA(1, 0, 2),(1, 1, 0, 7)7 - AIC:6129.881358323724
# Optimization terminated successfully.
#          Current function value: 2.993695
#          Iterations: 7
#          Function evaluations: 489
# SARIMA(1, 0, 2),(1, 1, 1, 7)7 - AIC:5843.717495518584
# Optimization terminated successfully.
#          Current function value: 2.992845
#          Iterations: 5
#          Function evaluations: 407
# SARIMA(1, 0, 2),(1, 1, 2, 7)7 - AIC:5844.061555149494
# Optimization terminated successfully.
#          Current function value: 3.162642
#          Iterations: 4
#          Function evaluations: 301
# SARIMA(1, 0, 2),(2, 0, 0, 7)7 - AIC:6172.826152708876
# Optimization terminated successfully.
#          Current function value: 3.023623
#          Iterations: 5
#          Function evaluations: 411
# SARIMA(1, 0, 2),(2, 0, 1, 7)7 - AIC:5904.016931908953
# Optimization terminated successfully.
#          Current function value: 3.023433
#          Iterations: 5
#          Function evaluations: 483
# SARIMA(1, 0, 2),(2, 0, 2, 7)7 - AIC:5905.647886795017
# Optimization terminated successfully.
#          Current function value: 3.094291
#          Iterations: 4
#          Function evaluations: 287
# SARIMA(1, 0, 2),(2, 1, 0, 7)7 - AIC:6039.678069051557
# Optimization terminated successfully.
#          Current function value: 2.993847
#          Iterations: 6
#          Function evaluations: 497
# SARIMA(1, 0, 2),(2, 1, 1, 7)7 - AIC:5846.014069255494
# Optimization terminated successfully.
#          Current function value: 2.992640
#          Iterations: 7
#          Function evaluations: 640
# SARIMA(1, 0, 2),(2, 1, 2, 7)7 - AIC:5845.662961001655
# Optimization terminated successfully.
#          Current function value: 3.437240
#          Iterations: 3
#          Function evaluations: 125
# SARIMA(1, 1, 0),(1, 0, 0, 7)7 - AIC:6701.743557789614
# Optimization terminated successfully.
#          Current function value: 3.142615
#          Iterations: 5
#          Function evaluations: 257
# SARIMA(1, 1, 0),(1, 0, 1, 7)7 - AIC:6129.813526345609
# Optimization terminated successfully.
#          Current function value: 3.138877
#          Iterations: 5
#          Function evaluations: 311
# SARIMA(1, 1, 0),(1, 0, 2, 7)7 - AIC:6124.532908812826
# Optimization terminated successfully.
#          Current function value: 3.268862
#          Iterations: 2
#          Function evaluations: 71
# SARIMA(1, 1, 0),(1, 1, 0, 7)7 - AIC:6373.742851687683
# Optimization terminated successfully.
#          Current function value: 3.108541
#          Iterations: 3
#          Function evaluations: 147
# SARIMA(1, 1, 0),(1, 1, 1, 7)7 - AIC:6063.437672956895
# Optimization terminated successfully.
#          Current function value: 3.108576
#          Iterations: 2
#          Function evaluations: 116
# SARIMA(1, 1, 0),(1, 1, 2, 7)7 - AIC:6065.505975562481
# Optimization terminated successfully.
#          Current function value: 3.289531
#          Iterations: 3
#          Function evaluations: 157
# SARIMA(1, 1, 0),(2, 0, 0, 7)7 - AIC:6416.006022176918
# Optimization terminated successfully.
#          Current function value: 3.138994
#          Iterations: 6
#          Function evaluations: 360
# SARIMA(1, 1, 0),(2, 0, 1, 7)7 - AIC:6124.759498567124
# Optimization terminated successfully.
#          Current function value: 3.138964
#          Iterations: 4
#          Function evaluations: 306
# SARIMA(1, 1, 0),(2, 0, 2, 7)7 - AIC:6126.701427687709
# Optimization terminated successfully.
#          Current function value: 3.213996
#          Iterations: 2
#          Function evaluations: 95
# SARIMA(1, 1, 0),(2, 1, 0, 7)7 - AIC:6268.864286627068
# Optimization terminated successfully.
#          Current function value: 3.108569
#          Iterations: 4
#          Function evaluations: 244
# SARIMA(1, 1, 0),(2, 1, 1, 7)7 - AIC:6065.491669817217
# Optimization terminated successfully.
#          Current function value: 3.108326
#          Iterations: 3
#          Function evaluations: 217
# SARIMA(1, 1, 0),(2, 1, 2, 7)7 - AIC:6067.018890169887
# Optimization terminated successfully.
#          Current function value: 3.295890
#          Iterations: 5
#          Function evaluations: 294
# SARIMA(1, 1, 1),(1, 0, 0, 7)7 - AIC:6428.394454338103
# Optimization terminated successfully.
#          Current function value: 3.032508
#          Iterations: 6
#          Function evaluations: 373
# SARIMA(1, 1, 1),(1, 0, 1, 7)7 - AIC:5917.326314913202
# Optimization terminated successfully.
#          Current function value: 3.031767
#          Iterations: 6
#          Function evaluations: 432
# SARIMA(1, 1, 1),(1, 0, 2, 7)7 - AIC:5917.882385844555
# Optimization terminated successfully.
#          Current function value: 3.151033
#          Iterations: 3
#          Function evaluations: 196
# SARIMA(1, 1, 1),(1, 1, 0, 7)7 - AIC:6146.212594430102
# Optimization terminated successfully.
#          Current function value: 3.005815
#          Iterations: 4
#          Function evaluations: 237
# SARIMA(1, 1, 1),(1, 1, 1, 7)7 - AIC:5865.326695011654
# Optimization terminated successfully.
#          Current function value: 3.005275
#          Iterations: 3
#          Function evaluations: 219
# SARIMA(1, 1, 1),(1, 1, 2, 7)7 - AIC:5866.275877978408
# Optimization terminated successfully.
#          Current function value: 3.164867
#          Iterations: 5
#          Function evaluations: 352
# SARIMA(1, 1, 1),(2, 0, 0, 7)7 - AIC:6175.161676780388
# Optimization terminated successfully.
#          Current function value: 3.031712
#          Iterations: 8
#          Function evaluations: 558
# SARIMA(1, 1, 1),(2, 0, 1, 7)7 - AIC:5917.774332117895
# Optimization terminated successfully.
#          Current function value: 3.030299
#          Iterations: 10
#          Function evaluations: 853
# SARIMA(1, 1, 1),(2, 0, 2, 7)7 - AIC:5917.022137928412
# Optimization terminated successfully.
#          Current function value: 3.104253
#          Iterations: 3
#          Function evaluations: 234
# SARIMA(1, 1, 1),(2, 1, 0, 7)7 - AIC:6057.084445001601
# Optimization terminated successfully.
#          Current function value: 3.006167
#          Iterations: 5
#          Function evaluations: 418
# SARIMA(1, 1, 1),(2, 1, 1, 7)7 - AIC:5868.012427313542
# Optimization terminated successfully.
#          Current function value: 3.005119
#          Iterations: 4
#          Function evaluations: 335
# SARIMA(1, 1, 1),(2, 1, 2, 7)7 - AIC:5867.971501593241
# Optimization terminated successfully.
#          Current function value: 3.286788
#          Iterations: 4
#          Function evaluations: 332
# SARIMA(1, 1, 2),(1, 0, 0, 7)7 - AIC:6412.663447985662
# Optimization terminated successfully.
#          Current function value: 3.033305
#          Iterations: 9
#          Function evaluations: 648
# SARIMA(1, 1, 2),(1, 0, 1, 7)7 - AIC:5920.8773465835675
# Optimization terminated successfully.
#          Current function value: 3.031521
#          Iterations: 10
#          Function evaluations: 824
# SARIMA(1, 1, 2),(1, 0, 2, 7)7 - AIC:5919.402316779622
# Optimization terminated successfully.
#          Current function value: 3.148620
#          Iterations: 6
#          Function evaluations: 377
# SARIMA(1, 1, 2),(1, 1, 0, 7)7 - AIC:6143.512542006252
# Optimization terminated successfully.
#          Current function value: 3.007876
#          Iterations: 7
#          Function evaluations: 490
# SARIMA(1, 1, 2),(1, 1, 1, 7)7 - AIC:5871.3417672346595
# Optimization terminated successfully.
#          Current function value: 3.009095
#          Iterations: 3
#          Function evaluations: 245
# SARIMA(1, 1, 2),(1, 1, 2, 7)7 - AIC:5875.71635859911
# Optimization terminated successfully.
#          Current function value: 3.161370
#          Iterations: 10
#          Function evaluations: 751
# SARIMA(1, 1, 2),(2, 0, 0, 7)7 - AIC:6170.349366770413
# Optimization terminated successfully.
#          Current function value: 3.034645
#          Iterations: 9
#          Function evaluations: 738
# SARIMA(1, 1, 2),(2, 0, 1, 7)7 - AIC:5925.4876000155955
# Optimization terminated successfully.
#          Current function value: 3.030713
#          Iterations: 10
#          Function evaluations: 961
# SARIMA(1, 1, 2),(2, 0, 2, 7)7 - AIC:5919.8295352837695
# Optimization terminated successfully.
#          Current function value: 3.122525
#          Iterations: 2
#          Function evaluations: 143
# SARIMA(1, 1, 2),(2, 1, 0, 7)7 - AIC:6094.678623611243
# Optimization terminated successfully.
#          Current function value: 3.007778
#          Iterations: 7
#          Function evaluations: 571
# SARIMA(1, 1, 2),(2, 1, 1, 7)7 - AIC:5873.1523737253365
# Optimization terminated successfully.
#          Current function value: 3.008213
#          Iterations: 5
#          Function evaluations: 462
# SARIMA(1, 1, 2),(2, 1, 2, 7)7 - AIC:5875.99862444843
# Optimization terminated successfully.
#          Current function value: 3.312089
#          Iterations: 3
#          Function evaluations: 142
# SARIMA(2, 0, 0),(1, 0, 0, 7)7 - AIC:6459.9488764243615
# Optimization terminated successfully.
#          Current function value: 3.038748
#          Iterations: 6
#          Function evaluations: 362
# SARIMA(2, 0, 0),(1, 0, 1, 7)7 - AIC:5929.4811135487125
# Optimization terminated successfully.
#          Current function value: 3.037748
#          Iterations: 5
#          Function evaluations: 355
# SARIMA(2, 0, 0),(1, 0, 2, 7)7 - AIC:5929.533521879943
# Optimization terminated successfully.
#          Current function value: 3.149410
#          Iterations: 2
#          Function evaluations: 96
# SARIMA(2, 0, 0),(1, 1, 0, 7)7 - AIC:6143.050750658709
# Optimization terminated successfully.
#          Current function value: 3.007254
#          Iterations: 4
#          Function evaluations: 240
# SARIMA(2, 0, 0),(1, 1, 1, 7)7 - AIC:5868.130928771181
# Optimization terminated successfully.
#          Current function value: 3.006575
#          Iterations: 3
#          Function evaluations: 215
# SARIMA(2, 0, 0),(1, 1, 2, 7)7 - AIC:5868.807134425937
# Optimization terminated successfully.
#          Current function value: 3.172661
#          Iterations: 3
#          Function evaluations: 184
# SARIMA(2, 0, 0),(2, 0, 0, 7)7 - AIC:6190.3427951850235
# Optimization terminated successfully.
#          Current function value: 3.037801
#          Iterations: 5
#          Function evaluations: 360
# SARIMA(2, 0, 0),(2, 0, 1, 7)7 - AIC:5929.636120764851
# Optimization terminated successfully.
#          Current function value: 3.035402
#          Iterations: 7
#          Function evaluations: 586
# SARIMA(2, 0, 0),(2, 0, 2, 7)7 - AIC:5926.9638792200185
# Optimization terminated successfully.
#          Current function value: 3.103244
#          Iterations: 2
#          Function evaluations: 118
# SARIMA(2, 0, 0),(2, 1, 0, 7)7 - AIC:6055.118381626897
# Optimization terminated successfully.
#          Current function value: 3.007148
#          Iterations: 4
#          Function evaluations: 293
# SARIMA(2, 0, 0),(2, 1, 1, 7)7 - AIC:5869.924414734271
# Optimization terminated successfully.
#          Current function value: 3.006486
#          Iterations: 4
#          Function evaluations: 331
# SARIMA(2, 0, 0),(2, 1, 2, 7)7 - AIC:5870.63547345858
# Optimization terminated successfully.
#          Current function value: 3.311867
#          Iterations: 3
#          Function evaluations: 175
# SARIMA(2, 0, 1),(1, 0, 0, 7)7 - AIC:6461.517017720039
# Optimization terminated successfully.
#          Current function value: 3.038669
#          Iterations: 6
#          Function evaluations: 430
# SARIMA(2, 0, 1),(1, 0, 1, 7)7 - AIC:5931.326482020624
# Optimization terminated successfully.
#          Current function value: 3.037733
#          Iterations: 5
#          Function evaluations: 416
# SARIMA(2, 0, 1),(1, 0, 2, 7)7 - AIC:5931.504292288939
# Optimization terminated successfully.
#          Current function value: 3.149305
#          Iterations: 2
#          Function evaluations: 114
# SARIMA(2, 0, 1),(1, 1, 0, 7)7 - AIC:6144.845300158449
# Optimization terminated successfully.
#          Current function value: 3.007253
#          Iterations: 4
#          Function evaluations: 282
# SARIMA(2, 0, 1),(1, 1, 1, 7)7 - AIC:5870.128333762832
# Optimization terminated successfully.
#          Current function value: 3.006569
#          Iterations: 3
#          Function evaluations: 251
# SARIMA(2, 0, 1),(1, 1, 2, 7)7 - AIC:5870.795635049275
# Optimization terminated successfully.
#          Current function value: 3.172531
#          Iterations: 3
#          Function evaluations: 212
# SARIMA(2, 0, 1),(2, 0, 0, 7)7 - AIC:6192.089529875903
# Optimization terminated successfully.
#          Current function value: 3.037697
#          Iterations: 6
#          Function evaluations: 499
# SARIMA(2, 0, 1),(2, 0, 1, 7)7 - AIC:5931.433046745174
# Optimization terminated successfully.
#          Current function value: 3.036224
#          Iterations: 4
#          Function evaluations: 369
# SARIMA(2, 0, 1),(2, 0, 2, 7)7 - AIC:5930.564228737927
# Optimization terminated successfully.
#          Current function value: 3.103224
#          Iterations: 2
#          Function evaluations: 139
# SARIMA(2, 0, 1),(2, 1, 0, 7)7 - AIC:6057.080218738697
# Optimization terminated successfully.
#          Current function value: 3.007150
#          Iterations: 4
#          Function evaluations: 337
# SARIMA(2, 0, 1),(2, 1, 1, 7)7 - AIC:5871.928005444333
# Optimization terminated successfully.
#          Current function value: 3.006481
#          Iterations: 4
#          Function evaluations: 372
# SARIMA(2, 0, 1),(2, 1, 2, 7)7 - AIC:5872.624448389044
# Optimization terminated successfully.
#          Current function value: 3.308107
#          Iterations: 6
#          Function evaluations: 433
# SARIMA(2, 0, 2),(1, 0, 0, 7)7 - AIC:6456.19246159352
# Optimization terminated successfully.
#          Current function value: 3.026341
#          Iterations: 6
#          Function evaluations: 508
# SARIMA(2, 0, 2),(1, 0, 1, 7)7 - AIC:5909.312434053916
# Optimization terminated successfully.
#          Current function value: 3.024382
#          Iterations: 5
#          Function evaluations: 472
# SARIMA(2, 0, 2),(1, 0, 2, 7)7 - AIC:5907.496679124433
# Optimization terminated successfully.
#          Current function value: 3.140030
#          Iterations: 3
#          Function evaluations: 216
# SARIMA(2, 0, 2),(1, 1, 0, 7)7 - AIC:6128.779059928457
# Optimization terminated successfully.
#          Current function value: 2.995275
#          Iterations: 4
#          Function evaluations: 313
# SARIMA(2, 0, 2),(1, 1, 1, 7)7 - AIC:5848.795460460911
# Optimization terminated successfully.
#          Current function value: 2.993723
#          Iterations: 4
#          Function evaluations: 373
# SARIMA(2, 0, 2),(1, 1, 2, 7)7 - AIC:5847.772123151708
# Optimization terminated successfully.
#          Current function value: 3.161916
#          Iterations: 5
#          Function evaluations: 441
# SARIMA(2, 0, 2),(2, 0, 0, 7)7 - AIC:6173.412223011023
# Optimization terminated successfully.
#          Current function value: 3.024066
#          Iterations: 7
#          Function evaluations: 669
# SARIMA(2, 0, 2),(2, 0, 1, 7)7 - AIC:5906.879786236012
# Optimization terminated successfully.
#          Current function value: 3.022967
#          Iterations: 9
#          Function evaluations: 966
# SARIMA(2, 0, 2),(2, 0, 2, 7)7 - AIC:5906.740676305813
# Optimization terminated successfully.
#          Current function value: 3.094043
#          Iterations: 3
#          Function evaluations: 244
# SARIMA(2, 0, 2),(2, 1, 0, 7)7 - AIC:6041.19625866428
# Optimization terminated successfully.
#          Current function value: 2.994639
#          Iterations: 4
#          Function evaluations: 376
# SARIMA(2, 0, 2),(2, 1, 1, 7)7 - AIC:5849.556220176171
# Optimization terminated successfully.
#          Current function value: 2.993641
#          Iterations: 5
#          Function evaluations: 516
# SARIMA(2, 0, 2),(2, 1, 2, 7)7 - AIC:5849.612051171514
# Optimization terminated successfully.
#          Current function value: 3.378557
#          Iterations: 3
#          Function evaluations: 160
# SARIMA(2, 1, 0),(1, 0, 0, 7)7 - AIC:6589.428202314923
# Optimization terminated successfully.
#          Current function value: 3.092043
#          Iterations: 5
#          Function evaluations: 314
# SARIMA(2, 1, 0),(1, 0, 1, 7)7 - AIC:6033.299947205271
# Optimization terminated successfully.
#          Current function value: 3.089475
#          Iterations: 5
#          Function evaluations: 363
# SARIMA(2, 1, 0),(1, 0, 2, 7)7 - AIC:6030.296968620225
# Optimization terminated successfully.
#          Current function value: 3.207565
#          Iterations: 2
#          Function evaluations: 95
# SARIMA(2, 1, 0),(1, 1, 0, 7)7 - AIC:6256.337054266313
# Optimization terminated successfully.
#          Current function value: 3.059574
#          Iterations: 3
#          Function evaluations: 183
# SARIMA(2, 1, 0),(1, 1, 1, 7)7 - AIC:5970.05044756634
# Optimization terminated successfully.
#          Current function value: 3.058367
#          Iterations: 2
#          Function evaluations: 140
# SARIMA(2, 1, 0),(1, 1, 2, 7)7 - AIC:5969.699880204346
# Optimization terminated successfully.
#          Current function value: 3.227121
#          Iterations: 3
#          Function evaluations: 194
# SARIMA(2, 1, 0),(2, 0, 0, 7)7 - AIC:6296.431458732275
# Optimization terminated successfully.
#          Current function value: 3.089328
#          Iterations: 7
#          Function evaluations: 502
# SARIMA(2, 1, 0),(2, 0, 1, 7)7 - AIC:6030.011200003118
# Optimization terminated successfully.
#          Current function value: 3.087907
#          Iterations: 4
#          Function evaluations: 340
# SARIMA(2, 1, 0),(2, 0, 2, 7)7 - AIC:6029.243574821039
# Optimization terminated successfully.
#          Current function value: 3.160735
#          Iterations: 2
#          Function evaluations: 119
# SARIMA(2, 1, 0),(2, 1, 0, 7)7 - AIC:6167.110911188595
# Optimization terminated successfully.
#          Current function value: 3.059137
#          Iterations: 4
#          Function evaluations: 290
# SARIMA(2, 1, 0),(2, 1, 1, 7)7 - AIC:5971.199312870398
# Optimization terminated successfully.
#          Current function value: 3.058181
#          Iterations: 3
#          Function evaluations: 252
# SARIMA(2, 1, 0),(2, 1, 2, 7)7 - AIC:5971.335961247997
# Optimization terminated successfully.
#          Current function value: 3.289609
#          Iterations: 7
#          Function evaluations: 452
# SARIMA(2, 1, 1),(1, 0, 0, 7)7 - AIC:6418.1582568899
# Optimization terminated successfully.
#          Current function value: 3.034346
#          Iterations: 8
#          Function evaluations: 582
# SARIMA(2, 1, 1),(1, 0, 1, 7)7 - AIC:5922.905730179156
# Optimization terminated successfully.
#          Current function value: 3.031759
#          Iterations: 12
#          Function evaluations: 985
# SARIMA(2, 1, 1),(1, 0, 2, 7)7 - AIC:5919.866051087069
# Optimization terminated successfully.
#          Current function value: 3.179134
#          Iterations: 2
#          Function evaluations: 117
# SARIMA(2, 1, 1),(1, 1, 0, 7)7 - AIC:6202.952406229906
# Optimization terminated successfully.
#          Current function value: 3.007911
#          Iterations: 7
#          Function evaluations: 495
# SARIMA(2, 1, 1),(1, 1, 1, 7)7 - AIC:5871.410001620438
# Optimization terminated successfully.
#          Current function value: 3.004803
#          Iterations: 9
#          Function evaluations: 771
# SARIMA(2, 1, 1),(1, 1, 2, 7)7 - AIC:5867.355280105088
# Optimization terminated successfully.
#          Current function value: 3.163066
#          Iterations: 10
#          Function evaluations: 805
# SARIMA(2, 1, 1),(2, 0, 0, 7)7 - AIC:6173.65347258433
# Optimization terminated successfully.
#          Current function value: 3.032510
#          Iterations: 11
#          Function evaluations: 899
# SARIMA(2, 1, 1),(2, 0, 1, 7)7 - AIC:5921.329150333345
# Optimization terminated successfully.
#          Current function value: 3.036958
#          Iterations: 12
#          Function evaluations: 1169
# SARIMA(2, 1, 1),(2, 0, 2, 7)7 - AIC:5931.994535465588
# Optimization terminated successfully.
#          Current function value: 3.124209
#          Iterations: 4
#          Function evaluations: 294
# SARIMA(2, 1, 1),(2, 1, 0, 7)7 - AIC:6097.959970692502
# Optimization terminated successfully.
#          Current function value: 3.006998
#          Iterations: 8
#          Function evaluations: 670
# SARIMA(2, 1, 1),(2, 1, 1, 7)7 - AIC:5871.6328313306885
# Optimization terminated successfully.
#          Current function value: 3.007018
#          Iterations: 7
#          Function evaluations: 666
# SARIMA(2, 1, 1),(2, 1, 2, 7)7 - AIC:5873.670780644343
# Optimization terminated successfully.
#          Current function value: 3.286717
#          Iterations: 6
#          Function evaluations: 516
# SARIMA(2, 1, 2),(1, 0, 0, 7)7 - AIC:6414.52455230472
# Optimization terminated successfully.
#          Current function value: 3.032548
#          Iterations: 7
#          Function evaluations: 578
# SARIMA(2, 1, 2),(1, 0, 1, 7)7 - AIC:5921.403603362409
# Optimization terminated successfully.
#          Current function value: 3.029951
#          Iterations: 7
#          Function evaluations: 641
# SARIMA(2, 1, 2),(1, 0, 2, 7)7 - AIC:5918.344124027428
# Optimization terminated successfully.
#          Current function value: 3.146754
#          Iterations: 11
#          Function evaluations: 853
# SARIMA(2, 1, 2),(1, 1, 0, 7)7 - AIC:6141.8759916647705
# Optimization terminated successfully.
#          Current function value: 3.005104
#          Iterations: 8
#          Function evaluations: 680
# SARIMA(2, 1, 2),(1, 1, 1, 7)7 - AIC:5867.942351339631
# Optimization terminated successfully.
#          Current function value: 3.003514
#          Iterations: 8
#          Function evaluations: 773
# SARIMA(2, 1, 2),(1, 1, 2, 7)7 - AIC:5866.8458855722
# Optimization terminated successfully.
#          Current function value: 3.159571
#          Iterations: 6
#          Function evaluations: 579
# SARIMA(2, 1, 2),(2, 0, 0, 7)7 - AIC:6168.844230045249
# Optimization terminated successfully.
#          Current function value: 3.031101
#          Iterations: 7
#          Function evaluations: 654
# SARIMA(2, 1, 2),(2, 0, 1, 7)7 - AIC:5920.583789018793
# Optimization terminated successfully.
#          Current function value: 3.033414
#          Iterations: 6
#          Function evaluations: 651
# SARIMA(2, 1, 2),(2, 0, 2, 7)7 - AIC:5927.089906006775
# Optimization terminated successfully.
#          Current function value: 3.102390
#          Iterations: 7
#          Function evaluations: 655
# SARIMA(2, 1, 2),(2, 1, 0, 7)7 - AIC:6057.455288994664
# Optimization terminated successfully.
#          Current function value: 3.005425
#          Iterations: 10
#          Function evaluations: 962
# SARIMA(2, 1, 2),(2, 1, 1, 7)7 - AIC:5870.567166192857
# Optimization terminated successfully.
#          Current function value: 3.003199
#          Iterations: 8
#          Function evaluations: 852
# SARIMA(2, 1, 2),(2, 1, 2, 7)7 - AIC:5868.231529110427

# %% [markdown]
# Thực hiện tìm kiếm tự động, bộ tham số tốt nhất cho mô hình là **SARIMA(1,0,0)x(1,1,2,7)** vì có chỉ số AIC thấp nhất (Cần tối ưu lại tham số cho tool tự động)
#
# Sau khi thực hiện tìm kiếm, bộ tham số tốt nhất cho mô hình là **SARIMA(1,0,2)x(2,1,2,7)** vì có chỉ số AIC thấp nhất ==> **Chọn bộ này**

# %%
# fit SARIMA 
sar = sm.tsa.statespace.SARIMAX(train_set['close'], 
                                order=(1,0,2), 
                                seasonal_order=(2,1,2,7)).fit()
sar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                             close   No. Observations:                  974
# Model:             SARIMAX(1, 0, 2)x(2, 1, 2, 7)   Log Likelihood               -2913.044
# Date:                           Fri, 15 Oct 2021   AIC                           5842.087
# Time:                                   04:42:38   BIC                           5881.081
# Sample:                               01-01-2019   HQIC                          5856.932
#                                     - 08-31-2021
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8707      0.036     23.992      0.000       0.800       0.942
# ma.L1         -0.3570      0.042     -8.595      0.000      -0.438      -0.276
# ma.L2         -0.2514      0.031     -8.007      0.000      -0.313      -0.190
# ar.S.L7       -0.9413      0.090    -10.476      0.000      -1.117      -0.765
# ar.S.L14      -0.0275      0.039     -0.699      0.485      -0.105       0.050
# ma.S.L7       -0.0237      0.082     -0.288      0.773      -0.185       0.138
# ma.S.L14      -0.7848      0.072    -10.963      0.000      -0.925      -0.645
# sigma2        23.9149      0.488     49.054      0.000      22.959      24.870
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.24   Jarque-Bera (JB):              8676.78
# Prob(Q):                              0.62   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.71   Skew:                            -2.24
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#Kiểm tra chất lượng qua residual
res = sar.resid

f1 = plot_acf(res.dropna())

f2 = plot_pacf(res.dropna())

# %% [markdown]
# **Walk Forward Validation**

# %%
train = train_set['close'].squeeze().values

train
# Out:
# array([ 0.  , 29.2 , 28.1 , 28.3 ,  0.  ,  0.  , 28.7 , 28.5 , 29.  ,
#        28.9 , 28.9 ,  0.  ,  0.  , 28.7 , 29.1 , 28.8 , 28.9 , 28.6 ,
#         0.  ,  0.  , 29.5 , 29.1 , 29.1 , 29.2 , 29.2 ,  0.  ,  0.  ,
#        28.9 , 29.  , 29.3 , 29.4 , 29.5 ,  0.  ,  0.  ,  0.  ,  0.  ,
#         0.  ,  0.  ,  0.  ,  0.  ,  0.  , 30.2 , 30.5 , 30.5 , 30.1 ,
#        30.2 ,  0.  ,  0.  , 30.4 , 30.3 , 30.4 , 30.1 , 30.5 ,  0.  ,
#         0.  , 31.  , 30.8 , 30.6 , 29.7 , 30.  ,  0.  ,  0.  , 30.4 ,
#        30.3 , 30.3 , 30.5 , 30.3 ,  0.  ,  0.  , 30.4 , 30.9 , 31.4 ,
#        31.5 , 31.7 ,  0.  ,  0.  , 31.9 , 31.3 , 31.  , 30.4 , 30.5 ,
#         0.  ,  0.  , 30.1 , 30.3 , 30.4 , 30.3 , 30.3 ,  0.  ,  0.  ,
#        30.3 , 30.3 , 30.1 , 30.2 , 30.2 ,  0.  ,  0.  , 30.8 , 30.5 ,
#        30.2 , 30.3 , 30.2 ,  0.  ,  0.  ,  0.  , 30.  , 29.9 , 29.7 ,
#        29.6 ,  0.  ,  0.  , 29.3 , 29.6 , 30.1 , 30.  , 30.1 ,  0.  ,
#         0.  ,  0.  ,  0.  ,  0.  , 29.7 , 30.  ,  0.  ,  0.  , 29.4 ,
#        29.5 , 29.5 , 29.1 , 29.3 ,  0.  ,  0.  , 29.2 , 29.1 , 29.5 ,
#        29.3 , 29.2 ,  0.  ,  0.  , 29.3 , 29.4 , 29.6 , 29.5 , 29.2 ,
#         0.  ,  0.  , 29.  , 28.9 , 29.2 , 29.1 , 29.  ,  0.  ,  0.  ,
#        28.7 , 28.6 , 28.9 , 28.5 , 28.7 ,  0.  ,  0.  , 28.6 , 28.6 ,
#        28.5 , 28.6 , 28.7 ,  0.  ,  0.  , 28.7 , 28.9 , 28.9 , 29.6 ,
#        29.5 ,  0.  ,  0.  , 29.5 , 29.2 , 29.  , 28.6 , 28.9 ,  0.  ,
#         0.  , 29.2 , 28.9 , 28.8 , 29.2 , 29.2 ,  0.  ,  0.  , 29.  ,
#        29.8 , 29.6 , 30.2 , 30.1 ,  0.  ,  0.  , 30.  , 30.2 , 30.7 ,
#        30.8 , 31.2 ,  0.  ,  0.  , 31.  , 30.8 , 30.7 , 23.7 , 23.4 ,
#         0.  ,  0.  , 23.  , 22.9 , 22.8 , 22.5 , 22.3 ,  0.  ,  0.  ,
#        22.  , 21.7 , 21.6 , 22.  , 21.9 ,  0.  ,  0.  , 22.  , 21.9 ,
#        21.7 , 21.7 , 21.9 ,  0.  ,  0.  , 22.  , 22.2 , 22.3 , 22.7 ,
#        22.6 ,  0.  ,  0.  , 22.5 , 22.5 , 22.2 , 22.1 , 22.2 ,  0.  ,
#         0.  ,  0.  , 22.1 , 22.  , 22.  , 21.9 ,  0.  ,  0.  , 21.9 ,
#        21.7 , 21.8 , 22.2 , 22.6 ,  0.  ,  0.  , 22.4 , 22.3 , 22.4 ,
#        23.1 , 23.2 ,  0.  ,  0.  , 23.3 , 23.2 , 23.  , 23.3 , 23.2 ,
#         0.  ,  0.  , 23.4 , 23.7 , 23.6 , 23.6 , 23.6 ,  0.  ,  0.  ,
#        23.2 , 23.3 , 23.7 , 24.  , 24.  ,  0.  ,  0.  , 24.5 , 24.4 ,
#        24.4 , 24.4 , 24.1 ,  0.  ,  0.  , 23.4 , 23.5 , 23.5 , 23.6 ,
#        23.6 ,  0.  ,  0.  , 23.7 , 23.7 , 24.3 , 24.1 , 24.2 ,  0.  ,
#         0.  , 24.6 , 24.6 , 24.6 , 24.6 , 24.8 ,  0.  ,  0.  , 24.7 ,
#        24.7 , 25.  , 24.5 , 24.4 ,  0.  ,  0.  , 24.1 , 24.2 , 23.9 ,
#        24.  , 23.2 ,  0.  ,  0.  , 23.4 , 23.6 , 23.2 , 22.9 , 23.1 ,
#         0.  ,  0.  , 22.6 , 22.6 , 23.1 , 23.  , 23.  ,  0.  ,  0.  ,
#        22.9 , 22.8 , 22.9 , 23.  , 23.2 ,  0.  ,  0.  , 23.  , 22.8 ,
#        22.5 , 22.5 , 22.7 ,  0.  ,  0.  , 22.8 , 22.7 , 22.9 , 22.6 ,
#        22.7 ,  0.  ,  0.  , 22.7 , 22.8 ,  0.  , 23.  , 23.  ,  0.  ,
#         0.  , 22.5 , 22.5 , 22.1 , 22.4 , 22.7 ,  0.  ,  0.  , 22.9 ,
#        23.5 , 23.3 , 23.9 , 23.8 ,  0.  ,  0.  , 24.3 , 24.5 , 24.5 ,
#         0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  , 23.6 , 23.  ,
#         0.  ,  0.  , 22.6 , 23.2 , 23.  , 24.  , 23.8 ,  0.  ,  0.  ,
#        23.6 , 23.7 , 25.6 , 25.5 , 26.4 ,  0.  ,  0.  , 26.4 , 26.6 ,
#        26.3 , 26.4 , 25.7 ,  0.  ,  0.  , 24.  , 25.1 , 24.6 , 25.5 ,
#        25.2 ,  0.  ,  0.  , 25.2 , 25.6 , 25.8 , 25.6 , 25.3 ,  0.  ,
#         0.  , 23.3 , 24.2 , 23.4 , 22.1 , 22.  ,  0.  ,  0.  , 20.9 ,
#        21.1 , 21.2 , 21.1 , 21.4 ,  0.  ,  0.  , 19.3 , 19.6 , 20.5 ,
#        19.7 , 19.7 ,  0.  ,  0.  , 18.2 , 17.8 , 18.6 ,  0.  , 19.1 ,
#         0.  ,  0.  , 20.6 , 20.3 , 20.2 , 20.  , 19.8 ,  0.  ,  0.  ,
#        20.  , 20.  , 20.2 , 20.4 , 21.  ,  0.  ,  0.  , 20.7 , 19.8 ,
#        20.4 , 20.3 , 20.3 ,  0.  ,  0.  , 20.1 , 20.3 , 20.5 ,  0.  ,
#         0.  ,  0.  ,  0.  , 20.3 , 20.3 , 20.8 , 21.2 , 21.4 ,  0.  ,
#         0.  , 21.7 , 21.8 , 21.7 , 21.4 , 21.7 ,  0.  ,  0.  , 21.8 ,
#        22.2 , 22.2 , 22.4 , 22.4 ,  0.  ,  0.  , 22.6 , 23.3 , 22.8 ,
#        22.9 , 22.9 ,  0.  ,  0.  , 25.1 , 24.8 , 25.5 , 25.3 , 25.2 ,
#         0.  ,  0.  , 25.4 , 25.5 , 25.6 , 24.5 , 24.5 ,  0.  ,  0.  ,
#        23.3 , 23.8 , 23.7 , 23.8 , 24.4 ,  0.  ,  0.  , 24.1 , 24.  ,
#        23.8 , 23.7 , 23.6 ,  0.  ,  0.  , 22.9 , 22.8 , 23.2 , 23.1 ,
#        23.  ,  0.  ,  0.  , 23.6 , 23.7 , 23.9 , 24.3 , 24.  ,  0.  ,
#         0.  , 23.9 , 24.  , 24.  , 24.  , 24.8 ,  0.  ,  0.  , 24.5 ,
#        24.6 , 24.4 , 24.2 , 23.2 ,  0.  ,  0.  , 21.8 , 22.9 , 22.2 ,
#        22.6 , 22.5 ,  0.  ,  0.  , 23.2 , 23.7 , 24.  , 23.8 , 23.7 ,
#         0.  ,  0.  , 23.8 , 25.4 , 25.4 , 25.5 , 25.3 ,  0.  ,  0.  ,
#        25.8 , 25.6 , 25.6 , 20.8 , 21.2 ,  0.  ,  0.  , 21.  , 21.1 ,
#        21.2 , 21.5 , 21.4 ,  0.  ,  0.  , 21.2 , 21.1 ,  0.  , 21.2 ,
#        21.1 ,  0.  ,  0.  , 20.8 , 20.6 , 20.9 , 20.9 , 20.8 ,  0.  ,
#         0.  , 21.2 , 21.3 , 21.2 , 21.5 , 21.7 ,  0.  ,  0.  , 22.  ,
#        22.3 , 22.5 , 22.2 , 22.2 ,  0.  ,  0.  , 22.6 , 22.4 , 22.5 ,
#        22.5 , 23.  ,  0.  ,  0.  , 23.6 , 24.  , 23.4 , 23.2 , 23.5 ,
#         0.  ,  0.  , 23.3 , 23.4 , 24.  , 24.5 , 24.7 ,  0.  ,  0.  ,
#        25.3 , 25.3 , 25.2 , 25.6 , 25.6 ,  0.  ,  0.  , 24.8 , 24.4 ,
#        23.8 , 23.9 , 24.1 ,  0.  ,  0.  , 24.5 , 25.  , 25.5 , 24.9 ,
#        25.1 ,  0.  ,  0.  , 25.4 , 25.3 , 25.4 , 26.4 , 26.5 ,  0.  ,
#         0.  , 26.2 , 27.2 , 27.2 , 27.2 , 27.3 ,  0.  ,  0.  , 27.3 ,
#        27.3 , 27.3 , 27.4 , 27.2 ,  0.  ,  0.  , 27.2 , 27.3 ,  0.  ,
#         0.  ,  0.  ,  0.  ,  0.  ,  0.  ,  0.  , 28.55, 27.95, 28.2 ,
#         0.  ,  0.  , 28.2 , 28.  , 28.25, 28.3 , 28.4 ,  0.  ,  0.  ,
#        28.95, 28.75, 28.1 , 27.3 , 27.95,  0.  ,  0.  , 27.8 , 27.7 ,
#        27.8 , 28.1 ,  0.  ,  0.  ,  0.  , 28.65, 29.35, 29.9 , 29.9 ,
#        30.2 ,  0.  ,  0.  , 30.35, 30.1 , 29.85, 29.85, 30.25,  0.  ,
#         0.  , 29.95, 27.9 , 28.3 , 28.95, 28.65,  0.  ,  0.  , 28.1 ,
#        27.8 , 27.5 , 25.6 , 26.8 ,  0.  ,  0.  , 26.65, 27.35, 28.1 ,
#        28.2 , 28.5 ,  0.  ,  0.  , 27.5 , 28.55,  0.  ,  0.  ,  0.  ,
#         0.  ,  0.  ,  0.  ,  0.  , 29.4 , 29.15, 31.1 ,  0.  ,  0.  ,
#        31.6 , 31.7 , 31.2 , 32.4 , 33.05,  0.  ,  0.  , 33.25, 33.  ,
#        33.25, 32.4 , 32.45,  0.  ,  0.  , 31.8 , 32.05, 32.75, 33.  ,
#        32.95,  0.  ,  0.  , 33.5 , 33.45, 33.5 , 33.95, 33.8 ,  0.  ,
#         0.  , 33.4 , 33.  , 32.45, 32.05, 32.45,  0.  ,  0.  , 33.  ,
#        33.3 , 33.3 , 33.85, 34.65,  0.  ,  0.  , 34.75, 34.75, 34.4 ,
#        34.4 , 34.4 ,  0.  ,  0.  , 35.15, 34.6 , 34.6 , 33.85, 33.1 ,
#         0.  ,  0.  , 33.7 , 33.6 ,  0.  , 32.5 , 33.4 ,  0.  ,  0.  ,
#        33.3 , 34.  , 33.8 , 34.65,  0.  ,  0.  ,  0.  ,  0.  , 34.45,
#        35.3 , 34.8 , 35.2 ,  0.  ,  0.  , 36.2 , 35.8 , 36.15, 36.2 ,
#        36.45,  0.  ,  0.  , 36.55, 36.25, 36.6 , 37.4 , 37.5 ,  0.  ,
#         0.  , 37.5 , 38.  , 38.45, 38.2 , 38.9 ,  0.  ,  0.  , 41.4 ,
#        42.1 , 44.6 , 45.9 , 45.3 ,  0.  ,  0.  , 43.  , 40.2 , 42.45,
#        34.1 , 34.65,  0.  ,  0.  , 34.1 , 35.35, 34.7 , 34.9 , 35.  ,
#         0.  ,  0.  , 34.75, 35.65, 35.8 , 36.2 , 36.35,  0.  ,  0.  ,
#        36.7 , 36.45, 35.7 , 35.95, 36.1 ,  0.  ,  0.  , 37.95, 36.  ,
#        36.55, 36.2 , 35.2 ,  0.  ,  0.  , 32.75, 32.9 , 31.75, 32.75,
#        33.6 ,  0.  ,  0.  , 32.15, 33.9 , 33.8 , 34.1 , 33.  ,  0.  ,
#         0.  , 32.7 , 33.15, 33.15, 34.15, 36.15,  0.  ,  0.  , 35.55,
#        35.8 , 35.5 , 36.  , 35.55,  0.  ,  0.  , 36.5 , 36.5 , 36.  ,
#        35.3 , 35.35,  0.  ,  0.  , 35.7 , 35.6 , 35.55, 35.3 , 33.6 ,
#         0.  ,  0.  , 32.  , 32.3 , 32.45, 31.95, 31.75,  0.  ,  0.  ,
#        32.15, 32.  ])

# %%
test = test_set['close'].squeeze().values

test
# Out:
# array([32.  ,  0.  ,  0.  ,  0.  ,  0.  , 32.05, 32.5 , 32.15, 32.45,
#        32.3 ,  0.  ,  0.  , 31.9 , 31.5 , 31.2 , 31.3 , 31.6 ,  0.  ,
#         0.  , 32.1 , 31.8 , 31.6 , 31.6 , 32.  ,  0.  ,  0.  , 31.5 ,
#        31.6 , 31.35, 31.55, 31.5 ])

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

history = [x for x in train]
predictions = list()
residuals = list()

# walk-forward validation
for t in range(len(test)):
    model = SARIMAX(endog=history,order=(1,0,2),seasonal_order=(2,1,2,7),trend='c',enforce_invertibility=False)
    model_fit = model.fit(maxiter=1000)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    residuals.append(yhat-obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
model = SARIMAX(endog=history,order=(1,0,2),seasonal_order=(2,1,2,7),trend='c',enforce_invertibility=False)
model_fit = model.fit(maxiter=1000)
# Out:
# predicted=33.185257, expected=32.000000
# predicted=33.397019, expected=0.000000
# predicted=15.635872, expected=0.000000
# predicted=-15.479938, expected=0.000000
# predicted=-0.841779, expected=0.000000
# predicted=28.922906, expected=32.050000
# predicted=31.875603, expected=32.500000
# predicted=31.034290, expected=32.150000
# predicted=31.064839, expected=32.450000
# predicted=31.377376, expected=32.300000
# predicted=-0.680919, expected=0.000000
# predicted=-0.419441, expected=0.000000
# predicted=33.347064, expected=31.900000
# predicted=33.017773, expected=31.500000
# predicted=32.588804, expected=31.200000
# predicted=28.652746, expected=31.300000
# predicted=29.829122, expected=31.600000
# predicted=0.825165, expected=0.000000
# predicted=-0.149327, expected=0.000000
# predicted=33.276747, expected=32.100000
# predicted=33.397813, expected=31.800000
# predicted=32.383780, expected=31.600000
# predicted=31.438698, expected=31.600000
# predicted=31.503024, expected=32.000000
# predicted=0.102987, expected=0.000000
# predicted=-0.045937, expected=0.000000
# predicted=33.349534, expected=31.500000
# predicted=32.745241, expected=31.600000
# predicted=32.576133, expected=31.350000
# predicted=29.387336, expected=31.550000
# predicted=30.413605, expected=31.500000

# %%
fig, axes = plt.subplots(1, 2)

residuals = pd.DataFrame(residuals)
residuals.plot(ax=axes[0])
axes[0].set_title('Residuals error')

residuals.plot(kind='kde', ax=axes[1])

plt.show()

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error

rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 7.297

# %%
plt.figure(figsize=(14, 10))
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
y = model_fit.predict(1,7)
print(y)
# Out:
# [0.03876269 0.03954488 0.03976087 0.03991959 0.03923958 0.0390044
#  0.0392976 ]
